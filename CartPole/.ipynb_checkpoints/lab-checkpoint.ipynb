# %%
import math
from random import randint, choice
from gym.envs.classic_control import CartPoleEnv
import tensorflow as tf
import pandas as pd
import numpy as np
import heapq

# %%
class Transaction:
    columns = ['state', 'action', 'reward', 'next_state', 'done', 'qvalue']
    def __init__(self, item):
        self.item = dict(zip(columns, item))
        
    def  __lt__(self, other):
        return self.item['id'] < other.item['id']
    
    def __repr__(self):
        return str(self.item['id'])

class Memory:
    def __init__(self, max_size):
        MAX_TRANSACTION = Transaction(Transaction.columns)
        MAX_TRANSACTION.item['id'] = -1
        self.d = [MAX_TRANSACTION]*max_size
        self.id = 0
        self.max_size = max_size
        print(self.d)
        
    def insert(self, item):
        print(self.d, len(self.d))
        self.id += 1
        item.item['id'] = self.id
        heapq.heapreplace(self.d, item)
        print(self.d, item)

    def batch(self, n):
        return heapq.nsmallest(n, self.d)
    
D = Memory(2)
item = Transaction([np.array([0,1,2,3]), 1,0,np.array([3,2,1,0]),0,10])

D.insert(item)
D.insert(item)
'''
print(D.d, D.batch(1))
item = Transaction([np.array([-1,1,2,3]), 1,0,np.array([3,2,1,0]),0,10])
D.insert(item)
print(D.d, D.batch(1))
'''
# Out:
# [-1, -1]
# [-1, -1] 2
# [-1, 1] 1
# [-1, 1] 2
# [2, 2] 2
# '\nprint(D.d, D.batch(1))\nitem = Transaction([np.array([-1,1,2,3]), 1,0,np.array([3,2,1,0]),0,10])\nD.insert(item)\nprint(D.d, D.batch(1))\n'

# %%
class QValue:
    def __init__(self, sess):
        self.state_size = 4
        self.action_size = 2
        self.input_size = self.state_size + self.action_size
        self.units = 16
        self.output_size = 1
        
        self.input = tf.placeholder(shape=(None, self.input_size), dtype=tf.float32)
        self.label = tf.placeholder(shape=(None, 1), dtype=tf.float32)
        
        self.build_network()
        self.sess = sess

    def build_network(self):
        self.layer_1 = tf.layers.dense(inputs=self.input, units=self.units)
        self.layer_2 = tf.layers.dense(inputs=self.layer_1, units=self.units/2)
        self.qvalue = tf.layers.dense(inputs=self.layer_2, units=self.output_size, activation=tf.nn.tanh)

        self.loss = tf.losses.mean_squared_error(labels=self.label, predictions=self.qvalue)
        self.best_action = tf.argmax(self.qvalue, axis=1)
        
    def get_best_action(self, state):
        batch = [0, 0]
        batch[0] = state + [0, 1]
        batch[1] = state + [1, 0]
        
        best_action = self.sess.run(self.best_action, feed_dict={self.input: batch})
        return best_action
    
    def update(self, batch):

# %%
T = 1000
batch_size = 1
D = Memory(T)
Q = QValue()

env = CartPoleEnv()
#env.theta_threshold_radians = 2 * math.pi * 1/4
state, _, _, _ = env.reset()

for _ in range(100):
    #env.render()
    #action = env.action_space.sample()
    actoin = Q.get_best_action(state)
    
    next_state, reward, done, _ = env.step(action) # take a random action
    #qvalue = calclulate_qvalue(next_state, Q, reward, GAMMA, done)
    
    one_round = (state, action, reward, next_state, done)
    D.insert(one_round)
    state = next_state
    
    batch = D.select_random_n(batch_size)
    add_qvalue(batch, Q, GAMMA)
    Q.update(batch)
    
    print(one_round, batch)
    
    if done:
        break
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
([-0.01655219,  0.17665435, -0.0527939 , -0.30072134]), 0, 1.0, array([-0.01301911, -0.01767692, -0.05880833, -0.02514476]))]
# (array([-0.18310111, -0.41607525,  0.15795068,  0.7486739 ]), 1, 1.0, array([-0.19142262, -0.22344377,  0.17292415,  0.50956823])) [(array([-0.01012777, -0.21010919, -0.0672746 ,  0.20876011]), 0, 1.0, array([-0.01432995, -0.40420791, -0.0630994 ,  0.47948577]))]
# (array([-0.19142262, -0.22344377,  0.17292415,  0.50956823]), 1, 1.0, array([-0.19589149, -0.03112569,  0.18311552,  0.2759802 ])) [(array([-0.04270838,  0.37066924, -0.01251381, -0.56862816]), 1, 1.0, array([-0.035295  ,  0.56596445, -0.02388638, -0.86522701]))]
# (array([-0.19589149, -0.03112569,  0.18311552,  0.2759802 ]), 1, 1.0, array([-0.19651401,  0.16097588,  0.18863512,  0.04618102])) [(array([-0.01655219,  0.17665435, -0.0527939 , -0.30072134]), 0, 1.0, array([-0.01301911, -0.01767692, -0.05880833, -0.02514476]))]
# (array([-0.19651401,  0.16097588,  0.18863512,  0.04618102]), 0, 1.0, array([-0.19329449, -0.03627974,  0.18955874,  0.39194622])) [(array([-0.02241411, -0.59838497, -0.05350969,  0.7516328 ]), 0, 1.0, array([-0.03438181, -0.79272978, -0.03847703,  1.02700842]))]
# (array([-0.19329449, -0.03627974,  0.18955874,  0.39194622]), 1, 1.0, array([-0.19402009,  0.15571777,  0.19739767,  0.1645058 ])) [(array([-0.19329449, -0.03627974,  0.18955874,  0.39194622]), 1, 1.0, array([-0.19402009,  0.15571777,  0.19739767,  0.1645058 ]))]
# (array([-0.19402009,  0.15571777,  0.19739767,  0.1645058 ]), 0, 1.0, array([-0.19090573, -0.04160168,  0.20068778,  0.5123959 ])) [(array([-0.10580643, -0.59794568,  0.05148191,  0.74127169]), 0, 1.0, array([-0.11776535, -0.79373913,  0.06630735,  1.04970175]))]
# (array([-0.19090573, -0.04160168,  0.20068778,  0.5123959 ]), 0, 1.0, array([-0.19173776, -0.2389004 ,  0.2109357 ,  0.86101115])) [(array([-0.01337265,  0.17823693, -0.05931122, -0.3357872 ]), 0, 1.0, array([-0.00980791, -0.01599299, -0.06602696, -0.0623819 ]))]

# %%
env.reset()
# Out:
# array([ 0.0088767 , -0.02736035,  0.02808166,  0.02312303])

# %%
action = env.action_space.sample()
print(action)
env.step(action)
# Out:
# 1
# (array([ 0.01433188,  0.80209443, -0.01991357, -1.13561044]), 1.0, False, {})
